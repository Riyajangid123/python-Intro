# %%
import pandas as pd
import matplotlib.pyplot as plt
df=pd.read_csv(r"C:\Users\DELL\Downloads\train.csv")
df
# Out:
#       Row ID        Order ID  Order Date   Ship Date       Ship Mode  \
# 0          1  CA-2017-152156  08/11/2017  11/11/2017    Second Class
# 1          2  CA-2017-152156  08/11/2017  11/11/2017    Second Class
# 2          3  CA-2017-138688  12/06/2017  16/06/2017    Second Class
# 3          4  US-2016-108966  11/10/2016  18/10/2016  Standard Class
# 4          5  US-2016-108966  11/10/2016  18/10/2016  Standard Class
# ...      ...             ...         ...         ...             ...
# 9795    9796  CA-2017-125920  21/05/2017  28/05/2017  Standard Class
# 9796    9797  CA-2016-128608  12/01/2016  17/01/2016  Standard Class
# 9797    9798  CA-2016-128608  12/01/2016  17/01/2016  Standard Class
# 9798    9799  CA-2016-128608  12/01/2016  17/01/2016  Standard Class
# 9799    9800  CA-2016-128608  12/01/2016  17/01/2016  Standard Class
#
#      Customer ID     Customer Name    Segment        Country             City  \
# ...

# %%
df.head()
# Out:
#    Row ID        Order ID  Order Date   Ship Date       Ship Mode Customer ID  \
# 0       1  CA-2017-152156  08/11/2017  11/11/2017    Second Class    CG-12520
# 1       2  CA-2017-152156  08/11/2017  11/11/2017    Second Class    CG-12520
# 2       3  CA-2017-138688  12/06/2017  16/06/2017    Second Class    DV-13045
# 3       4  US-2016-108966  11/10/2016  18/10/2016  Standard Class    SO-20335
# 4       5  US-2016-108966  11/10/2016  18/10/2016  Standard Class    SO-20335
#
#      Customer Name    Segment        Country             City       State  \
# 0      Claire Gute   Consumer  United States        Henderson    Kentucky
# 1      Claire Gute   Consumer  United States        Henderson    Kentucky
# 2  Darrin Van Huff  Corporate  United States      Los Angeles  California
# 3   Sean O'Donnell   Consumer  United States  Fort Lauderdale     Florida
# 4   Sean O'Donnell   Consumer  United States  Fort Lauderdale     Florida
#
# ...

# %%
df.tail()
# Out:
#       Row ID        Order ID  Order Date   Ship Date       Ship Mode  \
# 9795    9796  CA-2017-125920  21/05/2017  28/05/2017  Standard Class
# 9796    9797  CA-2016-128608  12/01/2016  17/01/2016  Standard Class
# 9797    9798  CA-2016-128608  12/01/2016  17/01/2016  Standard Class
# 9798    9799  CA-2016-128608  12/01/2016  17/01/2016  Standard Class
# 9799    9800  CA-2016-128608  12/01/2016  17/01/2016  Standard Class
#
#      Customer ID     Customer Name    Segment        Country     City  \
# 9795    SH-19975     Sally Hughsby  Corporate  United States  Chicago
# 9796    CS-12490  Cindy Schnelling  Corporate  United States   Toledo
# 9797    CS-12490  Cindy Schnelling  Corporate  United States   Toledo
# 9798    CS-12490  Cindy Schnelling  Corporate  United States   Toledo
# 9799    CS-12490  Cindy Schnelling  Corporate  United States   Toledo
#
#          State  Postal Code   Region       Product ID         Category  \
# ...

# %%
df.shape
# Out:
# (9800, 18)

# %%
df.dtypes
# Out:
# Row ID                    int64
# Order ID                 object
# Order Date       datetime64[ns]
# Ship Date        datetime64[ns]
# Ship Mode                object
# Customer ID              object
# Customer Name            object
# Segment                  object
# Country                  object
# City                     object
# State                    object
# Postal Code             float64
# Region                   object
# Product ID               object
# Category                 object
# Sub-Category             object
# Product Name             object
# Sales                   float64
# dtype: object

# %%
#count of unique customer id 
df['Customer ID'].nunique()
# Out:
# 793

# %%
#count of unique order id 
df['Order ID'].nunique()
# Out:
# 4922

# %%
#count of unique product id 
df['Product ID'].nunique()
# Out:
# 1861

# %%
# checking null values
df.isna().sum()
# Out:
# Row ID            0
# Order ID          0
# Order Date        0
# Ship Date         0
# Ship Mode         0
# Customer ID       0
# Customer Name     0
# Segment           0
# Country           0
# City              0
# State             0
# Postal Code      11
# Region            0
# Product ID        0
# Category          0
# Sub-Category      0
# Product Name      0
# Sales             0
# dtype: int64

# %%
# as the column have null values and it is not necessary for analysis so we drop it
df.drop('Postal Code',axis=1,inplace=True)

# %%
df['Order Date']=pd.to_datetime(df['Order Date'],dayfirst=True)
df['Ship Date']=pd.to_datetime(df['Ship Date'],dayfirst=True)

# %%
df['Sales'].sum()
# Out:
# 2261536.7827000003

# %%
Total_sales_by_order=df.groupby('Order ID')['Sales'].mean()
Total_sales_by_order
# Out:
# Order ID
# CA-2015-100006    377.970000
# CA-2015-100090    349.596000
# CA-2015-100293     91.056000
# CA-2015-100328      3.928000
# CA-2015-100363     10.688000
#                      ...
# US-2018-168802     18.368000
# US-2018-169320     85.715000
# US-2018-169488     28.430000
# US-2018-169502     56.705000
# US-2018-169551    224.139667
# Name: Sales, Length: 4922, dtype: float64

# %%
top10_sales_by_order=df.groupby('Order ID')['Sales'].sum().sort_values(ascending=False).head(10)
top10_sales_by_order
# Out:
# Order ID
# CA-2015-145317    23661.228
# CA-2017-118689    18336.740
# CA-2018-140151    14052.480
# CA-2018-127180    13716.458
# CA-2015-139892    10539.896
# CA-2018-166709    10499.970
# CA-2015-116904     9900.190
# CA-2017-117121     9892.740
# US-2017-107440     9135.190
# CA-2017-158841     8805.040
# Name: Sales, dtype: float64

# %%
Top10_products_by_sales=df.groupby('Product ID')['Sales'].sum().sort_values(ascending=False).head(10)
Top10_products_by_sales
# Out:
# Product ID
# TEC-CO-10004722    61599.824
# OFF-BI-10003527    27453.384
# TEC-MA-10002412    22638.480
# FUR-CH-10002024    21870.576
# OFF-BI-10001359    19823.479
# OFF-BI-10000545    19024.500
# TEC-CO-10001449    18839.686
# TEC-MA-10001127    18374.895
# OFF-BI-10004995    17965.068
# OFF-SU-10000151    17030.312
# Name: Sales, dtype: float64

# %%
top5_customers_by_sales=df.groupby('Customer ID')['Sales'].sum().sort_values(ascending=False).head()
top5_customers_by_sales
# Out:
# Customer ID
# SM-20320    25043.050
# TC-20980    19052.218
# RB-19360    15117.339
# TA-21385    14595.620
# AB-10105    14473.571
# Name: Sales, dtype: float64

# %%
#extracting year from date
df['Order Year']=df['Order Date'].dt.year

# %%
# extracting month from date
df['Order Month']=df['Order Date'].dt.month

# %%
sales_by_month=df.groupby('Order Month')['Sales'].sum()
sales_by_month
# Out:
# Order Month
# 1      94291.6296
# 2      59371.1154
# 3     197573.5872
# 4     136283.0006
# 5     154086.7237
# 6     145837.5233
# 7     145535.6890
# 8     157315.9270
# 9     300103.4117
# 10    199496.2947
# 11    350161.7110
# 12    321480.1695
# Name: Sales, dtype: float64

# %%
max_sale_by_year=df.groupby('Order Year')['Sales'].sum().sort_values(ascending=False).head(1)
max_sale_by_year
# Out:
# Order Year
# 2018    722052.0192
# Name: Sales, dtype: float64

# %%
df['Year Month']=df['Order Date'].dt.to_period('M')

# %%
#month_over_month_sales
monthly_sales=df.groupby('Year Month')['Sales'].sum().sort_index()
mom=monthly_sales.pct_change()*100
# Out:
# Year Month
# 2015-01            NaN
# 2015-02     -68.182562
# 2015-03    1121.396374
# 2015-04     -49.449412
# 2015-05     -15.274211
# 2015-06      45.163660
# 2015-07      -1.577349
# 2015-08     -19.726768
# 2015-09     200.999048
# 2015-10     -61.465286
# 2015-11     147.692389
# 2015-12     -12.502753
# 2016-01     -73.496058
# 2016-02     -33.849344
# 2016-03     170.589961
# 2016-04       5.612827
# 2016-05     -12.282252
# 2016-06     -21.229159
# 2016-07      21.224652
# 2016-08      28.698297
# 2016-09      71.473245
# 2016-10     -50.879192
# 2016-11     142.648125
# 2016-12      -0.937945
# 2017-01     -75.125308
# 2017-02      23.925178
# 2017-03     122.661869
# 2017-04     -24.401989
# 2017-05      46.476860
# 2017-06     -29.885891
# 2017-07      -3.533596
# 2017-08     -20.298601
# 2017-09     126.550118
# 2017-10     -13.889127
# 2017-11      32.699683
# 2017-12      21.086840
# 2018-01     -54.588601
# 2018-02     -54.179823
# 2018-03     195.484265
# ...

# %%
max_sales_by_region=df.groupby('Region')['Sales'].sum().sort_values(ascending=False).head(1)
max_sales_by_region
# Out:
# Region
# West    710219.6845
# Name: Sales, dtype: float64

# %%
state_wise_sales=df.groupby('State')['Sales'].sum()
state_wise_sales
# Out:
# State
# Alabama                  19510.6400
# Arizona                  35272.6570
# Arkansas                 11678.1300
# California              446306.4635
# Colorado                 31841.5980
# Connecticut              13384.3570
# Delaware                 27322.9990
# District of Columbia      2865.0200
# Florida                  88436.5320
# Georgia                  48219.1100
# Idaho                     4382.4860
# Illinois                 79236.5170
# Indiana                  48718.4000
# Iowa                      4443.5600
# Kansas                    2914.3100
# Kentucky                 36458.3900
# Louisiana                 9131.0500
# Maine                     1270.5300
# Maryland                 23705.5230
# Massachusetts            28634.4340
# Michigan                 76136.0740
# Minnesota                29863.1500
# Mississippi              10771.3400
# Missouri                 22205.1500
# Montana                   5589.3520
# Nebraska                  7464.9300
# ...

# %%
city_wise_totalsales=df.groupby('City')['Sales'].sum().sort_values(ascending=False).head(5)
city_wise_totalsales
# Out:
# City
# New York City    252462.547
# Los Angeles      173420.181
# Seattle          116106.322
# San Francisco    109041.120
# Philadelphia     108841.749
# Name: Sales, dtype: float64

# %%
Country_region_totalsales=df.groupby(['Country','Region'])['Sales'].sum().reset_index()
Country_region_totalsales
# Out:
#          Country   Region        Sales
# 0  United States  Central  492646.9132
# 1  United States     East  669518.7260
# 2  United States    South  389151.4590
# 3  United States     West  710219.6845

# %%
category_subcategory_totalsales=df.groupby(['Category','Sub-Category'])['Sales'].sum().reset_index()
category_subcategory_totalsales
# Out:
#            Category Sub-Category        Sales
# 0         Furniture    Bookcases  113813.1987
# 1         Furniture       Chairs  322822.7310
# 2         Furniture  Furnishings   89212.0180
# 3         Furniture       Tables  202810.6280
# 4   Office Supplies   Appliances  104618.4030
# 5   Office Supplies          Art   26705.4100
# 6   Office Supplies      Binders  200028.7850
# 7   Office Supplies    Envelopes   16128.0460
# 8   Office Supplies    Fasteners    3001.9600
# 9   Office Supplies       Labels   12347.7260
# 10  Office Supplies        Paper   76828.3040
# 11  Office Supplies      Storage  219343.3920
# 12  Office Supplies     Supplies   46420.3080
# 13       Technology  Accessories  164186.7000
# 14       Technology      Copiers  146248.0940
# 15       Technology     Machines  189238.6310
# 16       Technology       Phones  327782.4480

# %%
max_sales_by_subcategory=df.groupby('Sub-Category')['Sales'].sum().sort_values(ascending=False).head(1)
max_sales_by_subcategory
# Out:
# Sub-Category
# Phones    327782.448
# Name: Sales, dtype: float64

# %%
less_profitable_category=df.groupby('Category')['Sales'].sum().nsmallest(1)
less_profitable_category
# Out:
# Category
# Office Supplies    705422.334
# Name: Sales, dtype: float64

# %%
category_by_totalsales=df.groupby('Category')['Sales'].mean()
category_by_totalsales
# Out:
# Category
# Furniture          350.653790
# Office Supplies    119.381001
# Technology         456.401474
# Name: Sales, dtype: float64

# %%
count_by_segment=df.groupby('Segment')['Customer ID'].count()
count_by_segment
# Out:
# Segment
# Consumer       5101
# Corporate      2953
# Home Office    1746
# Name: Customer ID, dtype: int64

# %%
max_sale_by_segment=df.groupby('Segment')['Sales'].sum().nlargest(1)
max_sale_by_segment
# Out:
# Segment
# Consumer    1148060.531
# Name: Sales, dtype: float64

# %%
repeat_customers=df.groupby('Customer ID')['Order ID'].nunique().loc[lambda x:x>1]
repeat_customers.count()
# Out:
# 780

# %%
customer_sales=df.groupby('Customer ID')['Sales'].sum()
customer_orders=df.groupby('Customer ID')['Order ID'].nunique()
avg_order_value=customer_sales/customer_orders
avg_order_value
# Out:
# Customer ID
# AA-10315    1112.712000
# AA-10375     117.376667
# AA-10480     447.628000
# AA-10645     847.822500
# AB-10015     295.385333
#                ...
# XP-21865     215.878000
# YC-21895    1090.870000
# YS-21880     840.055500
# ZC-21910     617.362077
# ZD-21925     298.788800
# Length: 793, dtype: float64

# %%
df['Delivery Time']=(df['Ship Date']-df['Order Date']).dt.days

# %%
avg_time_ship_mode=df.groupby('Ship Mode')['Delivery Time'].mean().reset_index()
avg_time_ship_mode
# Out:
#         Ship Mode  Delivery Time
# 0     First Class       2.179214
# 1        Same Day       0.044610
# 2    Second Class       3.249211
# 3  Standard Class       5.008363

# %%
Fastest_ship_mode=df.groupby('Ship Mode')['Delivery Time'].mean().sort_values().nsmallest(1)
Fastest_ship_mode
# Out:
# Ship Mode
# Same Day    0.04461
# Name: Delivery Time, dtype: float64

# %%
Delivery_time_more_than_7_days=df[df['Delivery Time']>7]
Delivery_time_more_than_7_days
# Out:
# Empty DataFrame
# Columns: [Row ID, Order ID, Order Date, Ship Date, Ship Mode, Customer ID, Customer Name, Segment, Country, City, State, Postal Code, Region, Product ID, Category, Sub-Category, Product Name, Sales, Order Year, Order Month, Year Month, Delivery Time]
# Index: []
#
# [0 rows x 22 columns]

# %%
multi_region_customers=df.groupby('Customer ID')['Region'].nunique().loc[lambda x:x>1]
multi_region_customers
# Out:
# Customer ID
# AA-10315    3
# AA-10375    4
# AA-10480    3
# AA-10645    4
# AB-10015    2
#            ..
# XP-21865    4
# YC-21895    3
# YS-21880    3
# ZC-21910    4
# ZD-21925    3
# Name: Region, Length: 765, dtype: int64

# %%
category_sales=df.groupby('Category')['Sales'].sum()
plt.bar(category_sales.index,category_sales.values)
plt.xlabel('Category')
plt.ylabel('Sales')
plt.title('Category By Sales')
plt.show()

# %%
sub_category_sales=df.groupby('Sub-Category')['Sales'].sum()
plt.barh(sub_category_sales.index,sub_category_sales.values)
plt.xlabel('Sub-Category')
plt.ylabel('Sales')
plt.title('Sub-Category By Sales')
plt.show()

# %% [markdown]
# Sales peaked in December due to holiday season. Steady growth from June to November suggests seasonal promotions are effective.

# %%
monthly_sales=df.groupby('Order Month')['Sales'].sum()
plt.figure(figsize=(15,6))
plt.plot(year_month_sales.index.astype('str'),year_month_sales.values)
plt.xticks(rotation=(45))
plt.xlabel('Year_Month')
plt.ylabel('Sales')
plt.title('Sales Trend over Time')
plt.tight_layout()
plt.show()

# %% [markdown]
# West region shows highest sales, East region lags, suggesting regional marketing focus might improve sales.

# %%
region_wise_sales=df.groupby('Region')['Sales'].sum()
plt.bar(region_wise_sales.index,region_wise_sales.values)
plt.xlabel('Region')
plt.ylabel('Sales')
plt.title('Region_Wise_Sales')
plt.tight_layout()
plt.show()

# %%
segment_sales=df.groupby('Segment')['Sales'].sum()
plt.bar(segment_sales.index,segment_sales.values)
plt.xlabel('Customer Segment')
plt.ylabel('Sales')
plt.title('Segment VS Sales')
plt.ticklabel_format(style='plain',axis='y')
plt.tight_layout()
plt.show()

# %% [markdown]
# Top-selling product is Canon imageCLASS 2200 Advanced Copier, contributing 2.723% of total sales. This can help in stock planning and promotions.

# %%
top10_products=df.groupby('Product Name')['Sales'].sum().sort_values(ascending=False).head(10)
plt.barh(top10_products.index,top10_products.values)
plt.xlabel('Customer Sales')
plt.ylabel('Product_Name')
plt.title('Top 10 Products by Sales')
plt.figure(figsize=(10,8))
plt.tight_layout()
plt.show()

# %%
total_sales=df['Sales'].sum()

# %%
product_sales=df.groupby('Product Name')['Sales'].sum().sort_values(ascending=False).head(10)
percentage=(product_sales/total_sales)*100
percentage
# Out:
# Product Name
# Canon imageCLASS 2200 Advanced Copier                                          2.723804
# Fellowes PB500 Electric Punch Plastic Comb Binding Machine with Manual Bind    1.213926
# Cisco TelePresence System EX90 Videoconferencing Unit                          1.001022
# HON 5400 Series Task Chairs for Big and Tall                                   0.967067
# GBC DocuBind TL300 Electric Binding System                                     0.876549
# GBC Ibimaster 500 Manual ProClick Binding System                               0.841220
# Hewlett Packard LaserJet 3310 Copier                                           0.833048
# HP Designjet T520 Inkjet Large Format Printer - 24" Color                      0.812496
# GBC DocuBind P400 Electric Binding System                                      0.794374
# High Speed Automatic Electric Letter Opener                                    0.753042
# Name: Sales, dtype: float64

# %%
top5_state_sales=df.groupby('State')['Sales'].sum().nlargest(5)
plt.bar(top5_state_sales.index,top5_state_sales.values)
plt.xlabel('State')
plt.ylabel('Sales')
plt.title('Top5 States by Sales')
plt.tight_layout()
plt.show()

# %%
sales_by_category=df.groupby('Category')['Sales'].sum()
sales_by_segment=df.groupby('Segment')['Sales'].sum()
fig,ax=plt.subplots(1,2,figsize=(8,4),constrained_layout=True)
ax[0].barh(sales_by_category.index,sales_by_category.values)
ax[0].set_title('Sales By Category')
ax[1].bar(sales_by_segment.index,sales_by_segment.values)
ax[1].set_title('Sales by Segment')
plt.show()

# %%
plt.style.use('ggplot')

# %%
top5_state_sales=df.groupby('State')['Sales'].sum().nlargest(5)
plt.bar(top5_state_sales.index,top5_state_sales.values)
plt.xlabel('State')
plt.ylabel('Sales')
plt.title('Top5 States by Sales')
plt.tight_layout()
plt.show()

# %% [markdown]
# Consumer Segment contributes to highest sales (50.764619%) as it has more bulk orders.

# %%
plt.style.use('default')
sales_by_segment=df.groupby('Segment')['Sales'].sum()
plt.bar(sales_by_segment.index,sales_by_segment.values)
plt.ticklabel_format(style='plain',axis='y')

# %%
total_sales=df['Sales'].sum()

# %%
segment_sales=df.groupby('Segment')['Sales'].sum()
percentage=(segment_sales/total_sales)*100
percentage
# Out:
# Segment
# Consumer       50.764619
# Corporate      30.443638
# Home Office    18.791743
# Name: Sales, dtype: float64

# %%
mom
# Out:
# Year Month
# 2015-01            NaN
# 2015-02     -68.182562
# 2015-03    1121.396374
# 2015-04     -49.449412
# 2015-05     -15.274211
# 2015-06      45.163660
# 2015-07      -1.577349
# 2015-08     -19.726768
# 2015-09     200.999048
# 2015-10     -61.465286
# 2015-11     147.692389
# 2015-12     -12.502753
# 2016-01     -73.496058
# 2016-02     -33.849344
# 2016-03     170.589961
# 2016-04       5.612827
# 2016-05     -12.282252
# 2016-06     -21.229159
# 2016-07      21.224652
# 2016-08      28.698297
# 2016-09      71.473245
# 2016-10     -50.879192
# 2016-11     142.648125
# 2016-12      -0.937945
# 2017-01     -75.125308
# 2017-02      23.925178
# 2017-03     122.661869
# 2017-04     -24.401989
# 2017-05      46.476860
# 2017-06     -29.885891
# 2017-07      -3.533596
# 2017-08     -20.298601
# 2017-09     126.550118
# 2017-10     -13.889127
# 2017-11      32.699683
# 2017-12      21.086840
# 2018-01     -54.588601
# 2018-02     -54.179823
# 2018-03     195.484265
# ...

# %%
plt.figure(figsize=(12,8))
plt.plot(mom.index.astype('str'),mom.values)
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
