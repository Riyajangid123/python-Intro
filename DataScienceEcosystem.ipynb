# %% [markdown]
# Data Science Tools and Ecosystem

# %% [markdown]
# Introduction: In this notebook, Data Science Tools and Ecosystem are summarized

# %% [markdown]
# Data Science Languages: [Python,R,Scala]

# %% [markdown]
# Data Science Liabraries: Numpy, Pandas, Matplotlib

# %% [markdown]
# Data Science Tools
# _____________________________________
# Data Management Tools: MySQL, PostgreSQL
# ______________________________________
# Data Integration and Management Tools: Informatica,, Infosphere
# ______________________________________
# Data Visualization: Datameer, IBM cognos analytics

# %% [markdown]
# Below are few examples of evaluating arithematic expressions in Python

# %%
#This is a simple arithematic
a=(3*4)+5
print(a)
# Out:
# 17

# %%
#This will convert 200 minutes to hours by dividing by 60
m=200
result=200/60
print(result)
# Out:
# 3.3333333333333335

# %% [markdown]
# Objectives: Popular languages-[Python, R , Scala]
# Liabraries: Numpy, Pandas, Matplotlib

# %% [markdown]
# Author
# name-Riya Jangid
